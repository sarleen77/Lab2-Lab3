# %%
# Step 1: Import required library
import pandas as pd

# Step 2: Load the dataset
# Make sure the CSV file is in the same folder as this notebook
df = pd.read_csv("cardiovascular_risk_dataset.csv")

# Step 3: Display the shape of the dataset
print("Dataset shape (rows, columns):")
print(df.shape)

# Step 4: Preview the first few rows of the dataset
print("\nFirst 5 rows of the dataset:")
print(df.head())

# Step 5: Check column names and data types
print("\nDataset information:")
df.info()

# (Optional) Step 6: Display column names only
print("\nColumn names:")
print(df.columns)
